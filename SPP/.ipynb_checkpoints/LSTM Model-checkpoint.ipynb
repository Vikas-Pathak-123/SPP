# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader as data

# %%
start = '2010-01-01'
end = '2019-12-31'

df = data.DataReader('TSLA', 'yahoo', start, end)
df.head()
# Out:
#              High    Low   Open  Close    Volume  Adj Close
# Date
# 2010-06-29  5.000  3.508  3.800  4.778  93831500      4.778
# 2010-06-30  6.084  4.660  5.158  4.766  85935500      4.766
# 2010-07-01  5.184  4.054  5.000  4.392  41094000      4.392
# 2010-07-02  4.620  3.742  4.600  3.840  25699000      3.840
# 2010-07-06  4.000  3.166  4.000  3.222  34334500      3.222

# %%
df.tail()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2019-12-24  85.094002  82.538002  83.671997  85.050003  40273500  85.050003
# 2019-12-26  86.695999  85.269997  85.582001  86.188004  53169500  86.188004
# 2019-12-27  87.061996  85.222000  87.000000  86.075996  49728500  86.075996
# 2019-12-30  85.800003  81.851997  85.758003  82.940002  62932000  82.940002
# 2019-12-31  84.258003  80.416000  81.000000  83.666000  51428500  83.666000

# %%
df = df.reset_index()
df.head()
# Out:
#         Date   High    Low   Open  Close    Volume  Adj Close
# 0 2010-06-29  5.000  3.508  3.800  4.778  93831500      4.778
# 1 2010-06-30  6.084  4.660  5.158  4.766  85935500      4.766
# 2 2010-07-01  5.184  4.054  5.000  4.392  41094000      4.392
# 3 2010-07-02  4.620  3.742  4.600  3.840  25699000      3.840
# 4 2010-07-06  4.000  3.166  4.000  3.222  34334500      3.222

# %%
df = df.drop(['Date', 'Adj Close'],axis =1)
df.head()
# Out:
#     High    Low   Open  Close    Volume
# 0  5.000  3.508  3.800  4.778  93831500
# 1  6.084  4.660  5.158  4.766  85935500
# 2  5.184  4.054  5.000  4.392  41094000
# 3  4.620  3.742  4.600  3.840  25699000
# 4  4.000  3.166  4.000  3.222  34334500

# %%
plt.plot(df.Close)

# %%
ma100 = df.Close.rolling(100).mean()
ma100
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 2389    56.71740
# 2390    57.12264
# 2391    57.52190
# 2392    57.88446
# 2393    58.24452
# Name: Close, Length: 2394, dtype: float64

# %%
plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')

# %%
ma200 = df.Close.rolling(200).mean()
ma200
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 2389    52.43210
# 2390    52.57408
# 2391    52.71450
# 2392    52.85377
# 2393    53.00261
# Name: Close, Length: 2394, dtype: float64

# %%
plt.figure(figsize = (12,6))
plt.plot(df.Close)
plt.plot(ma100, 'r')
plt.plot(ma200, 'g')

# %%
df.shape
# Out:
# (2394, 5)

# %%
#splitting Data into traning and testing

data_training = pd.DataFrame(df['Close'][0:int(len(df)*0.70)])
data_testing = pd.DataFrame(df['Close'][int(len(df)*0.70):int(len(df))])

print(data_training.shape)
print(data_testing.shape)
# Out:
# (1675, 1)
# (719, 1)

# %%
data_training.head()
# Out:
#    Close
# 0  4.778
# 1  4.766
# 2  4.392
# 3  3.840
# 4  3.222

# %%
data_testing.head()
# Out:
#           Close
# 1675  51.198002
# 1676  51.400002
# 1677  49.245998
# 1678  49.998001
# 1679  50.004002

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (0,1))

# %%
data_training_array = scaler.fit_transform(data_training)
data_training_array
# Out:
# array([[0.02993635],
#        [0.02971432],
#        [0.02279456],
#        ...,
#        [0.94889726],
#        [0.96799142],
#        [0.9536338 ]])

# %%
data_training_array.shape
# Out:
# (1675, 1)

# %%
x_train = []
y_train = []

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100: i])
    y_train.append(data_training_array[i, 0])

x_train, y_train =np.array(x_train),np.array(y_train)

# %%
x_train.shape
# Out:
# (1575, 100, 1)

# %%
# ML Model

# %%
from keras.layers import Dense, Dropout, LSTM
from keras.models import Sequential

# %%
model = Sequential()
model.add(LSTM(units = 50, activation = 'relu', return_sequences = True,
              input_shape = (x_train.shape[1],1)))
model.add(Dropout(0.2))

model.add(LSTM(units = 60, activation = 'relu', return_sequences = True))
model.add(Dropout(0.3))

model.add(LSTM(units = 80, activation = 'relu', return_sequences = True))
model.add(Dropout(0.4))

model.add(LSTM(units = 120, activation = 'relu'))
model.add(Dropout(0.5))

model.add(Dense(units=1))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_8 (LSTM)                (None, 100, 50)           10400
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 100, 50)           0
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 100, 60)           26640
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 100, 60)           0
# _________________________________________________________________
# lstm_10 (LSTM)               (None, 100, 80)           45120
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 100, 80)           0
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 120)               96480
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 120)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 121
# =================================================================
# Total params: 178,761
# Trainable params: 178,761
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.fit(x_train, y_train, epochs = 50)
# Out:
# Epoch 1/50
# 50/50 [==============================] - 9s 187ms/step - loss: 0.0713
# Epoch 2/50
# 50/50 [==============================] - 11s 225ms/step - loss: 0.0141
# Epoch 3/50
# 50/50 [==============================] - 13s 254ms/step - loss: 0.0117
# Epoch 4/50
# 50/50 [==============================] - 13s 258ms/step - loss: 0.0106
# Epoch 5/50
# 50/50 [==============================] - 13s 257ms/step - loss: 0.0102
# Epoch 6/50
# 50/50 [==============================] - 13s 264ms/step - loss: 0.0093
# Epoch 7/50
# 50/50 [==============================] - 13s 268ms/step - loss: 0.0089
# Epoch 8/50
# 50/50 [==============================] - 13s 268ms/step - loss: 0.0085
# Epoch 9/50
# 50/50 [==============================] - 13s 266ms/step - loss: 0.0091
# Epoch 10/50
# 50/50 [==============================] - 14s 271ms/step - loss: 0.0083
# Epoch 11/50
# 50/50 [==============================] - 13s 255ms/step - loss: 0.0082
# Epoch 12/50
# 50/50 [==============================] - 13s 266ms/step - loss: 0.0077
# Epoch 13/50
# 50/50 [==============================] - 14s 274ms/step - loss: 0.0085
# Epoch 14/50
# 50/50 [==============================] - 14s 274ms/step - loss: 0.0073
# Epoch 15/50
# 50/50 [==============================] - 13s 259ms/step - loss: 0.0073
# Epoch 16/50
# 50/50 [==============================] - 14s 271ms/step - loss: 0.0063
# Epoch 17/50
# 50/50 [==============================] - 14s 284ms/step - loss: 0.0064
# Epoch 18/50
# 50/50 [==============================] - 13s 264ms/step - loss: 0.0066
# Epoch 19/50
# 50/50 [==============================] - 13s 251ms/step - loss: 0.0063
# Epoch 20/50
# 50/50 [==============================] - 13s 252ms/step - loss: 0.0063
# Epoch 21/50
# 50/50 [==============================] - 13s 257ms/step - loss: 0.0067
# Epoch 22/50
# 50/50 [==============================] - 13s 261ms/step - loss: 0.0058
# Epoch 23/50
# 50/50 [==============================] - 13s 255ms/step - loss: 0.0060
# Epoch 24/50
# 50/50 [==============================] - 14s 281ms/step - loss: 0.0060
# Epoch 25/50
# 50/50 [==============================] - 13s 260ms/step - loss: 0.0058
# Epoch 26/50
# 50/50 [==============================] - 13s 265ms/step - loss: 0.0055
# Epoch 27/50
# 50/50 [==============================] - 13s 269ms/step - loss: 0.0054
# Epoch 28/50
# 50/50 [==============================] - 14s 272ms/step - loss: 0.0059
# Epoch 29/50
# 50/50 [==============================] - 13s 263ms/step - loss: 0.0060
# Epoch 30/50
# 50/50 [==============================] - 13s 257ms/step - loss: 0.0053
# Epoch 31/50
# 50/50 [==============================] - 14s 276ms/step - loss: 0.0063
# Epoch 32/50
# 50/50 [==============================] - 15s 304ms/step - loss: 0.0054
# Epoch 33/50
# 50/50 [==============================] - 15s 296ms/step - loss: 0.0053
# Epoch 34/50
# 50/50 [==============================] - 14s 287ms/step - loss: 0.0054
# Epoch 35/50
# 50/50 [==============================] - 15s 303ms/step - loss: 0.0048
# Epoch 36/50
# 50/50 [==============================] - 13s 268ms/step - loss: 0.0056
# Epoch 37/50
# 50/50 [==============================] - 15s 297ms/step - loss: 0.0049
# Epoch 38/50
# 50/50 [==============================] - 13s 255ms/step - loss: 0.0052
# Epoch 39/50
# 50/50 [==============================] - 13s 254ms/step - loss: 0.0052
# Epoch 40/50
# 50/50 [==============================] - 13s 263ms/step - loss: 0.0052
# Epoch 41/50
# 50/50 [==============================] - 13s 258ms/step - loss: 0.0042
# Epoch 42/50
# 50/50 [==============================] - 13s 257ms/step - loss: 0.0048
# Epoch 43/50
# 50/50 [==============================] - 13s 256ms/step - loss: 0.0046
# Epoch 44/50
# 50/50 [==============================] - 13s 254ms/step - loss: 0.0046
# Epoch 45/50
# 50/50 [==============================] - 13s 255ms/step - loss: 0.0045
# Epoch 46/50
# 50/50 [==============================] - 13s 258ms/step - loss: 0.0043
# Epoch 47/50
# 50/50 [==============================] - 13s 264ms/step - loss: 0.0044
# Epoch 48/50
# 50/50 [==============================] - 13s 259ms/step - loss: 0.0045
# Epoch 49/50
# 50/50 [==============================] - 13s 254ms/step - loss: 0.0042
# Epoch 50/50
# 50/50 [==============================] - 13s 255ms/step - loss: 0.0042

# %%
model.save('keras_model.h5')

# %%
data_testing.head()
# Out:
#           Close
# 1675  51.198002
# 1676  51.400002
# 1677  49.245998
# 1678  49.998001
# 1679  50.004002

# %%
data_training.tail(100)
# Out:
#           Close
# 1575  40.139999
# 1576  40.806000
# 1577  42.740002
# 1578  42.282001
# 1579  41.692001
# ...         ...
# 1670  55.952000
# 1671  53.790001
# 1672  54.445999
# 1673  55.478001
# 1674  54.702000
#
# [100 rows x 1 columns]

# %%
past_100_days = data_training.tail(100)

# %%
final_df = past_100_days.append(data_testing, ignore_index = True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10840/3299050086.py in <module>
# ----> 1 final_df = past_100_days.append(data_testing, ignore_index = True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    9028
#    9029         Specifying `numeric_only=False` will also compute the quantile of
# -> 9030         datetime and timedelta data.
#    9031
#    9032         >>> df = pd.DataFrame({'A': [1, 2],
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_exceptions.py in find_stack_level()
#
# C:\ProgramData\Anaconda3\lib\inspect.py in stack(context)
#    1512 def stack(context=1):
#    1513     """Return a list of records for the stack above the caller's frame."""
# -> 1514     return getouterframes(sys._getframe(1), context)
#    1515
#    1516 def trace(context=1):
#
# C:\ProgramData\Anaconda3\lib\inspect.py in getouterframes(frame, context)
#    1489     framelist = []
#    1490     while frame:
# -> 1491         frameinfo = (frame,) + getframeinfo(frame, context)
#    1492         framelist.append(FrameInfo(*frameinfo))
#    1493         frame = frame.f_back
#
# C:\ProgramData\Anaconda3\lib\inspect.py in getframeinfo(frame, context)
#    1463         start = lineno - 1 - context//2
#    1464         try:
# -> 1465             lines, lnum = findsource(frame)
#    1466         except OSError:
#    1467             lines = index = None
#
# C:\ProgramData\Anaconda3\lib\inspect.py in findsource(object)
#     838         pat = re.compile(r'^(\s*def\s)|(\s*async\s+def\s)|(.*(?<!\w)lambda(:|\s))|^(\s*@)')
#     839         while lnum > 0:
# --> 840             if pat.match(lines[lnum]): break
#     841             lnum = lnum - 1
#     842         return lines, lnum
#
# IndexError: list index out of range

# %%
final_df.head()
# Out:
#        Close
# 0  40.139999
# 1  40.806000
# 2  42.740002
# 3  42.282001
# 4  41.692001

# %%
input_data =scaler.fit_transform(final_df)
input_data
# Out:
# array([[0.08624043],
#        [0.0994563 ],
#        [0.13783391],
#        [0.12874553],
#        [0.11703778],
#        [0.08743108],
#        [0.07000833],
#        [0.0872326 ],
#        [0.08385922],
#        [0.08945507],
#        [0.08441484],
#        [0.06961144],
#        [0.05949123],
#        [0.07989047],
#        [0.09759103],
#        [0.07989047],
#        [0.08381955],
#        [0.09441598],
#        [0.09274912],
#        [0.09235232],
#        [0.09937689],
#        [0.08334326],
#        [0.07445335],
#        [0.04691039],
#        [0.035917  ],
#        [0.03353578],
#        [0.04599755],
#        [0.05651465],
#        [0.06338056],
#        [0.04401322],
#        [0.02532049],
#        [0.03806014],
#        [0.00984248],
#        [0.01904994],
#        [0.01968489],
#        [0.03845695],
#        [0.02401085],
#        [0.02202644],
#        [0.04841851],
#        [0.05623684],
#        [0.07016714],
#        [0.06806366],
#        [0.04206855],
#        [0.04139386],
#        [0.01154901],
#        [0.00992182],
#        [0.03107516],
#        [0.02730482],
#        [0.05627658],
#        [0.05286346],
#        [0.05242691],
#        [0.05341908],
#        [0.07612021],
#        [0.07826328],
#        [0.07385799],
#        [0.09334448],
#        [0.09429698],
#        [0.11834742],
#        [0.11402154],
#        [0.11699804],
#        [0.13640513],
#        [0.16097152],
#        [0.16180502],
#        [0.14172325],
#        [0.13779417],
#        [0.15089097],
#        [0.19057823],
#        [0.18962573],
#        [0.19859504],
#        [0.2076041 ],
#        [0.20200816],
#        [0.20145254],
#        [0.20089692],
#        [0.23328173],
#        [0.22466963],
#        [0.23570268],
#        [0.25713376],
#        [0.26098343],
#        [0.27761242],
#        [0.30019448],
#        [0.29963886],
#        [0.29186012],
#        [0.29360638],
#        [0.28439892],
#        [0.28955831],
#        [0.2788824 ],
#        [0.28805019],
#        [0.28717702],
#        [0.31273566],
#        [0.31158468],
#        [0.32984086],
#        [0.35809818],
#        [0.35821725],
#        [0.40334163],
#        [0.40484975],
#        [0.40000792],
#        [0.35710601],
#        [0.3701234 ],
#        [0.39060206],
#        [0.37520338],
#        [0.30567134],
#        [0.30967975],
#        [0.26693651],
#        [0.28185897],
#        [0.28197804],
#        [0.28380364],
#        [0.28812952],
#        [0.28670081],
#        [0.2763027 ],
#        [0.26947654],
#        [0.26165813],
#        [0.25685596],
#        [0.26669844],
#        [0.31364842],
#        [0.30463944],
#        [0.32972178],
#        [0.32753897],
#        [0.32920583],
#        [0.2845974 ],
#        [0.30178193],
#        [0.30086917],
#        [0.33412707],
#        [0.36214625],
#        [0.3908402 ],
#        [0.39056239],
#        [0.39270546],
#        [0.39421358],
#        [0.4744612 ],
#        [0.49501926],
#        [0.46049131],
#        [0.47517563],
#        [0.49041549],
#        [0.52950747],
#        [0.51490256],
#        [0.46779377],
#        [0.49620983],
#        [0.48604987],
#        [0.48132711],
#        [0.50224231],
#        [0.49029642],
#        [0.50255978],
#        [0.51220379],
#        [0.53506366],
#        [0.52069689],
#        [0.51458508],
#        [0.5361749 ],
#        [0.57094099],
#        [0.55530417],
#        [0.52407027],
#        [0.4623169 ],
#        [0.51347377],
#        [0.50887007],
#        [0.56471003],
#        [0.58042619],
#        [0.57201257],
#        [0.57879899],
#        [0.54335828],
#        [0.54784298],
#        [0.50458386],
#        [0.53216649],
#        [0.52331625],
#        [0.52141125],
#        [0.49565421],
#        [0.52089529],
#        [0.54712862],
#        [0.58010871],
#        [0.61963716],
#        [0.64309246],
#        [0.64055236],
#        [0.6384887 ],
#        [0.668135  ],
#        [0.69008211],
#        [0.71706946],
#        [0.75814576],
#        [0.70782226],
#        [0.7145295 ],
#        [0.78175973],
#        [0.80045246],
#        [0.77933878],
#        [0.76370196],
#        [0.757352  ],
#        [0.76703567],
#        [0.78354559],
#        [0.80819146],
#        [0.81152518],
#        [0.78787154],
#        [0.72786436],
#        [0.76306701],
#        [0.72143508],
#        [0.72484812],
#        [0.68916935],
#        [0.58784771],
#        [0.51537877],
#        [0.53280152],
#        [0.54403298],
#        [0.58836367],
#        [0.59749172],
#        [0.5732428 ],
#        [0.59058614],
#        [0.55800294],
#        [0.59241182],
#        [0.580585  ],
#        [0.59907925],
#        [0.59304677],
#        [0.64908513],
#        [0.63749646],
#        [0.65436351],
#        [0.61709721],
#        [0.61951816],
#        [0.57348095],
#        [0.55800294],
#        [0.58308529],
#        [0.66722224],
#        [0.70619521],
#        [0.69928949],
#        [0.73917523],
#        [0.73246813],
#        [0.7002024 ],
#        [0.71000507],
#        [0.7335397 ],
#        [0.7277057 ],
#        [0.73000751],
#        [0.68639125],
#        [0.66869061],
#        [0.63059088],
#        [0.6444417 ],
#        [0.68976463],
#        [0.69039958],
#        [0.67103224],
#        [0.66154705],
#        [0.66829381],
#        [0.69139182],
#        [0.70218673],
#        [0.7002024 ],
#        [0.67714405],
#        [0.65706228],
#        [0.6811922 ],
#        [0.65257766],
#        [0.73310308],
#        [0.72937256],
#        [0.74318371],
#        [0.78846683],
#        [0.79707893],
#        [0.81767665],
#        [0.7783862 ],
#        [0.77366344],
#        [0.7441758 ],
#        [0.6830972 ],
#        [0.65888795],
#        [0.65991985],
#        [0.64293365],
#        [0.63749646],
#        [0.64344961],
#        [0.64515613],
#        [0.67138938],
#        [0.69865454],
#        [0.69992459],
#        [0.70607607],
#        [0.65075199],
#        [0.70095635],
#        [0.69702735],
#        [0.70131364],
#        [0.70087702],
#        [0.68115253],
#        [0.70159145],
#        [0.71706946],
#        [0.68595463],
#        [0.65932442],
#        [0.62725717],
#        [0.62852722],
#        [0.58288681],
#        [0.58419652],
#        [0.56316232],
#        [0.56002694],
#        [0.60546887],
#        [0.56399575],
#        [0.47739811],
#        [0.50450445],
#        [0.49136799],
#        [0.50434571],
#        [0.49775761],
#        [0.49220142],
#        [0.49220142],
#        [0.54145336],
#        [0.51486289],
#        [0.52518151],
#        [0.52994402],
#        [0.54006423],
#        [0.51502163],
#        [0.55101796],
#        [0.5303409 ],
#        [0.54204864],
#        [0.54704922],
#        [0.54998605],
#        [0.51025912],
#        [0.51545817],
#        [0.50625072],
#        [0.50097233],
#        [0.49501926],
#        [0.53296026],
#        [0.52494344],
#        [0.54038178],
#        [0.59507076],
#        [0.6431718 ],
#        [0.63523431],
#        [0.63071003],
#        [0.65277614],
#        [0.63459936],
#        [0.60376234],
#        [0.59534857],
#        [0.60598482],
#        [0.58034685],
#        [0.54895422],
#        [0.52653089],
#        [0.54129454],
#        [0.52537999],
#        [0.56181294],
#        [0.54879548],
#        [0.53835771],
#        [0.54613646],
#        [0.62483621],
#        [0.6140413 ],
#        [0.61844659],
#        [0.63094802],
#        [0.62408226],
#        [0.63932213],
#        [0.66750005],
#        [0.65722109],
#        [0.67885057],
#        [0.68496239],
#        [0.68984396],
#        [0.66245981],
#        [0.62971779],
#        [0.65039485],
#        [0.67690591],
#        [0.662182  ],
#        [0.69587644],
#        [0.67579467],
#        [0.6539667 ],
#        [0.61181882],
#        [0.61515254],
#        [0.65892761],
#        [0.54077867],
#        [0.52168906],
#        [0.542763  ],
#        [0.57423504],
#        [0.56887718],
#        [0.6155495 ],
#        [0.62118502],
#        [0.61832759],
#        [0.61249359],
#        [0.66357105],
#        [0.6869072 ],
#        [0.70821921],
#        [0.68270024],
#        [0.65122827],
#        [0.60308758],
#        [0.61971664],
#        [0.61269192],
#        [0.592253  ],
#        [0.60852477],
#        [0.59582486],
#        [0.58816519],
#        [0.66095161],
#        [0.64638636],
#        [0.58602204],
#        [0.58193438],
#        [0.56506717],
#        [0.5341509 ],
#        [0.52220501],
#        [0.54593798],
#        [0.51645034],
#        [0.48644675],
#        [0.49692419],
#        [0.39770603],
#        [0.31277532],
#        [0.34591422],
#        [0.29174105],
#        [0.35147042],
#        [0.42850339],
#        [0.50303607],
#        [0.47755684],
#        [0.4392983 ],
#        [0.49898793],
#        [0.48402587],
#        [0.45684012],
#        [0.48168432],
#        [0.44544985],
#        [0.43147989],
#        [0.45394288],
#        [0.48065242],
#        [0.44160018],
#        [0.41433502],
#        [0.41469224],
#        [0.40369885],
#        [0.42270905],
#        [0.45684012],
#        [0.45612569],
#        [0.48001746],
#        [0.48489897],
#        [0.41862124],
#        [0.45687978],
#        [0.49132833],
#        [0.48815335],
#        [0.50752069],
#        [0.50025798],
#        [0.48454183],
#        [0.44846609],
#        [0.41754966],
#        [0.42667779],
#        [0.41897845],
#        [0.38833984],
#        [0.41877998],
#        [0.38115645],
#        [0.39726949],
#        [0.39242765],
#        [0.39639639],
#        [0.41588281],
#        [0.44747392],
#        [0.41973248],
#        [0.44787073],
#        [0.46739688],
#        [0.44513237],
#        [0.55772513],
#        [0.54419171],
#        [0.55042267],
#        [0.60773101],
#        [0.65007737],
#        [0.65805452],
#        [0.70940978],
#        [0.71119579],
#        [0.76143981],
#        [0.68889154],
#        [0.72726908],
#        [0.66888909],
#        [0.61380316],
#        [0.61134254],
#        [0.64702146],
#        [0.65694328],
#        [0.67849343],
#        [0.65079165],
#        [0.61951816],
#        [0.52343532],
#        [0.51668849],
#        [0.51565658],
#        [0.55379605],
#        [0.56951228],
#        [0.55558198],
#        [0.54665233],
#        [0.55522477],
#        [0.52041908],
#        [0.57038537],
#        [0.57498899],
#        [0.56062222],
#        [0.53423023],
#        [0.49303485],
#        [0.47013532],
#        [0.51502163],
#        [0.506727  ],
#        [0.46914315],
#        [0.44132237],
#        [0.47295308],
#        [0.48366866],
#        [0.67694557],
#        [0.67150853],
#        [0.6469818 ],
#        [0.7961265 ],
#        [0.75949515],
#        [0.68849458],
#        [0.70055954],
#        [0.70421073],
#        [0.66940505],
#        [0.63388493],
#        [0.62102621],
#        [0.5021629 ],
#        [0.51383098],
#        [0.56724999],
#        [0.56621823],
#        [0.56010627],
#        [0.57090133],
#        [0.55681229],
#        [0.52740406],
#        [0.50021824],
#        [0.49283645],
#        [0.48692304],
#        [0.43648054],
#        [0.40389725],
#        [0.40473068],
#        [0.33444455],
#        [0.42278838],
#        [0.39873794],
#        [0.44279083],
#        [0.43850453],
#        [0.46128507],
#        [0.45985628],
#        [0.42064531],
#        [0.47644561],
#        [0.47370717],
#        [0.47676308],
#        [0.47906496],
#        [0.48426402],
#        [0.51835534],
#        [0.51017979],
#        [0.34051669],
#        [0.5228003 ],
#        [0.48438301],
#        [0.45969755],
#        [0.40822321],
#        [0.3293249 ],
#        [0.28412111],
#        [0.33269836],
#        [0.30920346],
#        [0.29074888],
#        [0.31674406],
#        [0.31995871],
#        [0.38742708],
#        [0.36833747],
#        [0.33710365],
#        [0.3215859 ],
#        [0.32535616],
#        [0.45707819],
#        [0.43469461],
#        [0.53931021],
#        [0.60296858],
#        [0.61864507],
#        [0.59899992],
#        [0.62844773],
#        [0.65607019],
#        [0.66452347],
#        [0.64464017],
#        [0.64329079],
#        [0.67146886],
#        [0.68432744],
#        [0.68079524],
#        [0.60447663],
#        [0.63404374],
#        [0.65495895],
#        [0.6725801 ],
#        [0.69587644],
#        [0.69254273],
#        [0.66880976],
#        [0.6319006 ],
#        [0.58284714],
#        [0.66289628],
#        [0.65464132],
#        [0.67031781],
#        [0.64372741],
#        [0.68067624],
#        [0.71246569],
#        [0.71726793],
#        [0.7306028 ],
#        [0.71040202],
#        [0.73889742],
#        [0.74528704],
#        [0.74465209],
#        [0.78509345],
#        [0.7411199 ],
#        [0.67250062],
#        [0.62729683],
#        [0.61118387],
#        [0.54137395],
#        [0.55879663],
#        [0.4620391 ],
#        [0.58387905],
#        [0.54435053],
#        [0.61475573],
#        [0.61050911],
#        [0.52049841],
#        [0.48176365],
#        [0.55054167],
#        [0.61908154],
#        [0.6206294 ],
#        [0.63324998],
#        [0.65880862],
#        [0.667897  ],
#        [0.61685906],
#        [0.65666547],
#        [0.66309476],
#        [0.66809533],
#        [0.48930425],
#        [0.47604872],
#        [0.43108308],
#        [0.44664042],
#        [0.46858753],
#        [0.46596817],
#        [0.47025439],
#        [0.5151407 ],
#        [0.50819538],
#        [0.52879311],
#        [0.5314918 ],
#        [0.56506717],
#        [0.54867641],
#        [0.51014005],
#        [0.50335355],
#        [0.5312934 ],
#        [0.52720559],
#        [0.51275941],
#        [0.49529707],
#        [0.51160851],
#        [0.50271852],
#        [0.4904949 ],
#        [0.44552918],
#        [0.45934041],
#        [0.47545344],
#        [0.47184184],
#        [0.538834  ],
#        [0.55923325],
#        [0.45965788],
#        [0.42223276],
#        [0.3872286 ],
#        [0.38603803],
#        [0.38742708],
#        [0.41739093],
#        [0.44429887],
#        [0.41429536],
#        [0.4365202 ],
#        [0.44048894],
#        [0.38282331],
#        [0.35924908],
#        [0.35123227],
#        [0.3755606 ],
#        [0.37722745],
#        [0.33956419],
#        [0.32325276],
#        [0.35242292],
#        [0.3804421 ],
#        [0.39548356],
#        [0.4004048 ],
#        [0.43739329],
#        [0.4242965 ],
#        [0.44783106],
#        [0.35246258],
#        [0.38095805],
#        [0.37397307],
#        [0.37044095],
#        [0.38532367],
#        [0.35500253],
#        [0.35214511],
#        [0.34690639],
#        [0.3746081 ],
#        [0.36615466],
#        [0.37421121],
#        [0.33249988],
#        [0.33706391],
#        [0.31626777],
#        [0.27249278],
#        [0.22292337],
#        [0.24804538],
#        [0.23701232],
#        [0.21843867],
#        [0.25848315],
#        [0.30186134],
#        [0.30309165],
#        [0.27023056],
#        [0.26141998],
#        [0.25006945],
#        [0.24030637],
#        [0.19065763],
#        [0.21169191],
#        [0.21026312],
#        [0.19589635],
#        [0.12723741],
#        [0.10473468],
#        [0.10362344],
#        [0.05460972],
#        [0.06556337],
#        [0.04627536],
#        [0.03861576],
#        [0.04321945],
#        [0.03671076],
#        [0.02456647],
#        [0.        ],
#        [0.05806251],
#        [0.06992899],
#        [0.10707623],
#        [0.10132163],
#        [0.13457953],
#        [0.15132751],
#        [0.12021276],
#        [0.13866734],
#        [0.14267575],
#        [0.18279956],
#        [0.18164865],
#        [0.18835575],
#        [0.16132874],
#        [0.17021872],
#        [0.17728303],
#        [0.16188435],
#        [0.15993969],
#        [0.17410805],
#        [0.17656867],
#        [0.19129258],
#        [0.18089456],
#        [0.22197086],
#        [0.21482715],
#        [0.2038735 ],
#        [0.20276226],
#        [0.23792516],
#        [0.23665518],
#        [0.26237248],
#        [0.29578919],
#        [0.29134424],
#        [0.30118665],
#        [0.29594793],
#        [0.31436285],
#        [0.30444103],
#        [0.32226059],
#        [0.34095332],
#        [0.19784102],
#        [0.19474545],
#        [0.22542365],
#        [0.25118069],
#        [0.248601  ],
#        [0.21780372],
#        [0.21974839],
#        [0.19585669],
#        [0.20550069],
#        [0.21609712],
#        [0.23546454],
#        [0.22240741],
#        [0.19859504],
#        [0.22236775],
#        [0.16132874],
#        [0.14553318],
#        [0.16259871],
#        [0.18994328],
#        [0.18609361],
#        [0.16613091],
#        [0.17136962],
#        [0.12870579],
#        [0.14299323],
#        [0.13934203],
#        [0.14533477],
#        [0.16962336],
#        [0.18510144],
#        [0.18272015],
#        [0.16553562],
#        [0.20085726],
#        [0.1924039 ],
#        [0.20962817],
#        [0.22451089],
#        [0.2703893 ],
#        [0.26550779],
#        [0.26284877],
#        [0.2533635 ],
#        [0.26122158],
#        [0.25606227],
#        [0.26840496],
#        [0.244672  ],
#        [0.24709288],
#        [0.17557643],
#        [0.19736481],
#        [0.25237134],
#        [0.25066474],
#        [0.24566416],
#        [0.2608247 ],
#        [0.25463348],
#        [0.21454934],
#        [0.20819938],
#        [0.23316266],
#        [0.24240978],
#        [0.26018967],
#        [0.26102318],
#        [0.27352461],
#        [0.30952094],
#        [0.31321187],
#        [0.32059373],
#        [0.32940431],
#        [0.30948127],
#        [0.29578919],
#        [0.30404415],
#        [0.30047229],
#        [0.47906496],
#        [0.59197519],
#        [0.59030834],
#        [0.54470767],
#        [0.5399055 ],
#        [0.53954836],
#        [0.53315866],
#        [0.54966857],
#        [0.54867641],
#        [0.58582372],
#        [0.6213835 ],
#        [0.62773345],
#        [0.65928475],
#        [0.67849343],
#        [0.6633329 ],
#        [0.67619163],
#        [0.68738334],
#        [0.67873158],
#        [0.7165535 ],
#        [0.68758182],
#        [0.69794026],
#        [0.61146168],
#        [0.6245584 ],
#        [0.59511043],
#        [0.60451644],
#        [0.59915858],
#        [0.6187244 ],
#        [0.62400278],
#        [0.61142202],
#        [0.6008651 ],
#        [0.62277255],
#        [0.63721865],
#        [0.67416748],
#        [0.68948682],
#        [0.71718845],
#        [0.71206888],
#        [0.80378617],
#        [0.79382454],
#        [0.85002172],
#        [0.89324117],
#        [0.89939265],
#        [0.9534865 ],
#        [0.97741794],
#        [1.        ],
#        [0.99777737],
#        [0.93554787],
#        [0.9499543 ]])

# %%
input_data.shape
# Out:
# (819, 1)

# %%
x_test=[]
y_test=[]

for i in range(input_data.shape[0]):
        x_test.append(input_data[i-100: i])
        y_test.append(input_data[i,0])

# %%
x_test, y_test = np.array(x_test), np.array(y_test)
print(x_test.shape)
print(y_test.shape)
# Out:
# (819,)
# (819,)

# %%
#making prediction

y_predicted = model.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10840/1077978905.py in <module>
#       1 #making prediction
#       2
# ----> 3 y_predicted = model.predict(x_test)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     128       raise ValueError('{} is not supported in multi-worker mode.'.format(
#     129           method.__name__))
# --> 130     return method(self, *args, **kwargs)
#     131
#     132   return tf_decorator.make_decorator(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1567     with self.distribute_strategy.scope():
#    1568       # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1569       data_handler = data_adapter.DataHandler(
#    1570           x=x,
#    1571           batch_size=batch_size,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution)
#    1103
#    1104     adapter_cls = select_data_adapter(x, y)
# -> 1105     self._adapter = adapter_cls(
#    1106         x,
#    1107         y,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     263                **kwargs):
#     264     super(TensorLikeDataAdapter, self).__init__(x, y, **kwargs)
# --> 265     x, y, sample_weights = _process_tensorlike((x, y, sample_weights))
#     266     sample_weight_modes = broadcast_sample_weight_modes(
#     267         sample_weights, sample_weight_modes)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in _process_tensorlike(inputs)
#    1019     return x
#    1020
# -> 1021   inputs = nest.map_structure(_convert_numpy_and_scipy, inputs)
#    1022   return nest.list_to_tuple(inputs)
#    1023
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\util\nest.py in map_structure(func, *structure, **kwargs)
#     633
#     634   return pack_sequence_as(
# --> 635       structure[0], [func(*x) for x in entries],
#     636       expand_composites=expand_composites)
#     637
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\util\nest.py in <listcomp>(.0)
#     633
#     634   return pack_sequence_as(
# --> 635       structure[0], [func(*x) for x in entries],
#     636       expand_composites=expand_composites)
#     637
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in _convert_numpy_and_scipy(x)
#    1014       if issubclass(x.dtype.type, np.floating):
#    1015         dtype = backend.floatx()
# -> 1016       return ops.convert_to_tensor(x, dtype=dtype)
#    1017     elif scipy_sparse and scipy_sparse.issparse(x):
#    1018       return _scipy_sparse_to_sparse_tensor(x)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1497
#    1498     if ret is None:
# -> 1499       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1500
#    1501     if ret is NotImplemented:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\tensor_conversion_registry.py in _default_conversion_function(***failed resolving arguments***)
#      50 def _default_conversion_function(value, dtype, name, as_ref):
#      51   del as_ref  # Unused.
# ---> 52   return constant_op.constant(value, dtype, name=name)
#      53
#      54
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py in constant(value, dtype, shape, name)
#     261     ValueError: if called on a symbolic tensor.
#     262   """
# --> 263   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     264                         allow_broadcast=True)
#     265
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     273       with trace.Trace("tf.constant"):
#     274         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 275     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     276
#     277   g = ops.get_default_graph()
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     298 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     299   """Implementation of eager constant."""
# --> 300   t = convert_to_eager_tensor(value, ctx, dtype)
#     301   if shape is None:
#     302     return t
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#      96       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#      97   ctx.ensure_initialized()
# ---> 98   return ops.EagerTensor(value, ctx.device_name, dtype)
#      99
#     100
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type numpy.ndarray).

# %%
y_predicted.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10840/1188954959.py in <module>
# ----> 1 y_predicted.shape
#
# NameError: name 'y_predicted' is not defined

# %%
Scaler.scale_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10840/587557633.py in <module>
# ----> 1 Scaler.scale_
#
# NameError: name 'Scaler' is not defined

# %%
scale_factor = 1/0.02099517
y_predicted = y_predicted * scale_factor
y_test = y_test * scale_factor
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10840/4200691113.py in <module>
#       1 scale_factor = 1/0.02099517
# ----> 2 y_predicted = y_predicted * scale_factor
#       3 y_test = y_test * scale_factor
#
# NameError: name 'y_predicted' is not defined

# %%
plt.figure(figsize=(12,6))
plt.plot(y_test, 'b', label = 'Original Price')
plt.plot(y_predicted, 'r', label = 'Predicted Price')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
pt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10840/2563669324.py in <module>
#       1 plt.figure(figsize=(12,6))
#       2 plt.plot(y_test, 'b', label = 'Original Price')
# ----> 3 plt.plot(y_predicted, 'r', label = 'Predicted Price')
#       4 plt.xlabel('Time')
#       5 plt.ylabel('Price')
#
# NameError: name 'y_predicted' is not defined

# %%
plt.figure(figsize=(12,6))
plt.plot(y_test, 'b', label = 'Original Price')
plt.plot(y_predicted, 'r', label = 'Predicted Price')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10840/3904504795.py in <module>
#       1 plt.figure(figsize=(12,6))
#       2 plt.plot(y_test, 'b', label = 'Original Price')
# ----> 3 plt.plot(y_predicted, 'r', label = 'Predicted Price')
#       4 plt.xlabel('Time')
#       5 plt.ylabel('Price')
#
# NameError: name 'y_predicted' is not defined
